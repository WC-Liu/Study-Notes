# %% [markdown]
# 1.创建一个元组，包含元素：10, 20, "python", True，并打印出来。

# %%
t = (10, 20, 'python', True)
print(t)
# Out:
# (10, 20, 'python', True)

# %% [markdown]
# 2.写出正确的单元素元组（元素为 50）。

# %%
t = (50,)
print(t)
# Out:
# (50,)

# %% [markdown]
# 3.有元组 t = ("a", "b", "c", "d")
# 取出第 2 个元素
# 取出最后 2 个元素
# 尝试修改第 1 个元素为 "x"，观察结果

# %%
t =('a', 'b', 'c', 'd')
print(t[1])
print(t[-2:])
t[0] = 'x'
# Out:
# b
# ('c', 'd')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 4
#       2 print(t[1])
#       3 print(t[-2:])
# ----> 4 t[0] = 'x'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# 4.元祖解包

# %%
name, age, city = ("张三", 20, "上海")
print(name, age, city)
# Out:
# 张三 20 上海

# %% [markdown]
# 第 5 题
# 判断对错并解释：

# %%
t = (1, [2, 3])
t[1].append(4)
print(t)
# Out:
# (1, [2, 3, 4])

# %% [markdown]
# 第 6 题
# 综合操作：

# %%
t = (5, 2, 8, 2, 9, 2)
print(len(t))
print(max(t))
print(t.count(2))
# Out:
# 6
# 9
# 3
